# %% [markdown]
# # Machine Learning in Finance - Data Analysis
#
# This notebook will focus on analyzing the data we chosen.
#
# *Authors:* [Mina Attia](https://people.epfl.ch/mina.attia), [Arnaud Felber](https://people.epfl.ch/arnaud.felber), ??? ???, [Rami Atassi](https://people.epfl.ch/rami.atassi) & [Paulo Ribeiro](https://people.epfl.ch/paulo.ribeirodecarvalho)

# %% [markdown]
# ## Import
#
# Libraries and python script needed.

# %%
from helpers import load_data_df
from data_analysis import asset_price_plot, assets_information

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data
#
# Load the raw data.

# %%
file_path = 'data/temp/signed_predictors_all_wide.csv'
data = load_data_df(file_path=file_path)

data.head()
# Out:
#    permno       date  AM  AOP  AbnormalAccruals  Accruals  AccrualsBM  \
# 0   10000 1986-01-01 NaN  NaN               NaN       NaN         NaN
# 1   10000 1986-02-01 NaN  NaN               NaN       NaN         NaN
# 2   10000 1986-03-01 NaN  NaN               NaN       NaN         NaN
# 3   10000 1986-04-01 NaN  NaN               NaN       NaN         NaN
# 4   10000 1986-05-01 NaN  NaN               NaN       NaN         NaN
#
#    Activism1  Activism2  AdExp  ...  sinAlgo  skew1  std_turn  tang  \
# 0        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 1        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 2        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 3        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 4        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
#
#    zerotrade  zerotradeAlt1  zerotradeAlt12  STreversal     Price      Size
# ...

# %% [markdown]
# ## Data analysis

# %%
# Select one precise asset to see the price evolution
permno_id = 10014
asset_price_plot(data=data, permno_id=permno_id)

# %%
asset_info = assets_information(data=data)
# Out:
# %%%%%%%%%% Asset Information %%%%%%%%%%
# Number of assets: 37774
# Oldest date in dataset: 1925-12-01 00:00:00
# Latest date in dataset: 2024-10-01 00:00:00
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
asset_info.head(n=10)
# Out:
#    permno  data_quantity  date_from    date_to date_window  ratio_price_nan
# 0   10000             28 1985-12-01 1988-03-01    821 days         0.392857
# 1   10001            390 1985-12-01 2018-05-01  11839 days         0.028205
# 2   10002            330 1985-12-01 2013-05-01  10013 days         0.015152
# 3   10003            126 1985-12-01 1996-05-01   3804 days         0.055556
# 4   10004              1 1986-01-01 1986-01-01      0 days         1.000000
# 5   10005             78 1985-12-01 1992-05-01   2343 days         0.153846
# 6   10006            714 1925-12-01 1985-05-01  21701 days         0.018207
# 7   10007             60 1985-12-01 1990-11-01   1796 days         0.283333
# 8   10008             42 1985-12-01 1989-05-01   1247 days         0.190476
# 9   10009            186 1985-12-01 2001-05-01   5630 days         0.043011

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ## Results
#
# Try to show relevant correlation or information about different potential predictors in our dataset.
