# %% [markdown]
# # Machine Learning in Finance - Data Analysis
#
# This notebook will focus on analyzing the data we chosen.
#
# *Authors:* [Mina Attia](https://people.epfl.ch/mina.attia), [Arnaud Felber](https://people.epfl.ch/arnaud.felber), [Milos Novakovic](https://people.epfl.ch/milos.novakovic), [Rami Atassi](https://people.epfl.ch/rami.atassi) & [Paulo Ribeiro](https://people.epfl.ch/paulo.ribeirodecarvalho)

# %% [markdown]
# ## Import
#
# Libraries and python script needed.

# %%
from helpers import load_data_df, select_time_window
from data_analysis import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data
#
# Load the raw data.

# %%
file_path = 'data/signed_predictors_all_wide.csv'
data = load_data_df(file_path=file_path)

data.head()
# Out:
#    permno       date  AM  AOP  AbnormalAccruals  Accruals  AccrualsBM  \
# 0   10000 1986-01-01 NaN  NaN               NaN       NaN         NaN
# 1   10000 1986-02-01 NaN  NaN               NaN       NaN         NaN
# 2   10000 1986-03-01 NaN  NaN               NaN       NaN         NaN
# 3   10000 1986-04-01 NaN  NaN               NaN       NaN         NaN
# 4   10000 1986-05-01 NaN  NaN               NaN       NaN         NaN
#
#    Activism1  Activism2  AdExp  ...  sinAlgo  skew1  std_turn  tang  \
# 0        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 1        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 2        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 3        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
# 4        NaN        NaN    NaN  ...      NaN    NaN       NaN   NaN
#
#    zerotrade  zerotradeAlt1  zerotradeAlt12  STreversal     Price      Size
# 0        NaN            NaN             NaN      0.0000 -1.475907 -9.686575
# 1        NaN   4.785175e-08             NaN     25.7143 -1.178655 -9.389323
# 2        NaN   1.023392e-07             NaN    -36.5385 -1.490091 -9.700759
# 3        NaN   7.467463e-08             NaN      9.8592 -1.386294 -9.627207
# 4        NaN   7.649551e-08             NaN     22.2656 -1.134423 -9.375336
#
# [5 rows x 214 columns]

# %% [markdown]
# ## Data analysis

# %%
# Select one precise asset to see the price evolution
permno_id = 10014
asset_price_plot(data=data, permno_id=permno_id)

# %%
asset_info_df,  ratio_nan_attributes = assets_information(data=data)
display(asset_info_df.head(n=10))
display(ratio_nan_attributes.head(n=10))
# Out:
# %%%%%%%%%% Asset Information %%%%%%%%%%
# Number of assets: 37774
# Oldest date in dataset: 1925-12-01 00:00:00
# Latest date in dataset: 2023-12-01 00:00:00
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#    permno  data_quantity  date_from    date_to  month_window  ratio_nan_price  \
# 0   10000             28 1985-12-01 1988-03-01            27         0.392857
# 1   10001            390 1985-12-01 2018-05-01           389         0.028205
# 2   10002            330 1985-12-01 2013-05-01           329         0.015152
# 3   10003            126 1985-12-01 1996-05-01           125         0.055556
# 4   10004              1 1986-01-01 1986-01-01             0         1.000000
# 5   10005             78 1985-12-01 1992-05-01            77         0.153846
# 6   10006            714 1925-12-01 1985-05-01           713         0.018207
# 7   10007             60 1985-12-01 1990-11-01            59         0.283333
# 8   10008             42 1985-12-01 1989-05-01            41         0.190476
# 9   10009            186 1985-12-01 2001-05-01           185         0.043011
#
#    ratio_nan_overall
# 0           0.891173
# 1           0.401246
# 2           0.533033
# 3           0.757001
# 4           0.990566
# 5           0.648464
# 6           0.568020
# 7           0.774607
# 8           0.699686
# 9           0.654139
#               AM       AOP  AbnormalAccruals  Accruals  AccrualsBM  Activism1  \
# permno
# 10000   0.928571  1.000000          1.000000  1.000000    1.000000        1.0
# 10001   0.071795  0.784615          0.107692  0.092308    0.971795        1.0
# 10002   0.321212  0.854545          1.000000  0.345455    1.000000        1.0
# 10003   0.896825  1.000000          1.000000  0.944444    1.000000        1.0
# 10004   1.000000  1.000000          1.000000  1.000000    1.000000        1.0
# 10005   0.371795  1.000000          0.384615  0.384615    1.000000        1.0
# 10006   0.450980  1.000000          0.781513  0.450980    0.995798        1.0
# 10007   0.633333  1.000000          0.800000  0.800000    1.000000        1.0
# 10008   0.523810  0.428571          0.714286  0.714286    0.976190        1.0
# 10009   0.586022  1.000000          1.000000  0.612903    1.000000        1.0
#
#         Activism2     AdExp    AgeIPO  AnalystRevision  ...  sinAlgo  skew1  \
# permno                                                  ...
# 10000         1.0  0.928571  1.000000         1.000000  ...      1.0    1.0
# 10001         1.0  1.000000  1.000000         0.451282  ...      1.0    1.0
# 10002         1.0  0.527273  0.896970         0.730303  ...      1.0    1.0
# 10003         1.0  1.000000  0.730159         0.817460  ...      1.0    1.0
# 10004         1.0  1.000000  1.000000         1.000000  ...      1.0    1.0
# 10005         1.0  1.000000  1.000000         1.000000  ...      1.0    1.0
# 10006         1.0  0.753501  1.000000         1.000000  ...      1.0    1.0
# 10007         1.0  0.633333  1.000000         1.000000  ...      1.0    1.0
# 10008         1.0  0.523810  0.261905         0.404762  ...      1.0    1.0
# 10009         1.0  0.586022  1.000000         0.844086  ...      1.0    1.0
#
#         std_turn      tang  zerotrade  zerotradeAlt1  zerotradeAlt12  \
# permno
# 10000   1.000000  0.571429   0.535714       0.392857        0.785714
# 10001   0.087179  1.000000   0.038462       0.028205        0.056410
# 10002   0.084848  1.000000   0.027273       0.015152        0.048485
# 10003   0.238095  1.000000   0.087302       0.055556        0.142857
# 10004   1.000000  1.000000   1.000000       1.000000        1.000000
# 10005   0.448718  1.000000   0.589744       0.243590        0.794872
# 10006   0.728291  0.434174   0.023810       0.018207        0.033613
# 10007   1.000000  1.000000   0.416667       0.266667        0.633333
# 10008   0.785714  0.428571   0.285714       0.190476        0.452381
# 10009   0.166667  1.000000   0.064516       0.043011        0.102151
#
#         STreversal     Price      Size
# permno
# 10000     0.321429  0.392857  0.392857
# 10001     0.023077  0.028205  0.028205
# 10002     0.009091  0.015152  0.015152
# 10003     0.039683  0.055556  0.055556
# 10004     1.000000  1.000000  1.000000
# 10005     0.128205  0.153846  0.153846
# 10006     0.015406  0.018207  0.018207
# 10007     0.016667  0.283333  0.283333
# 10008     0.142857  0.190476  0.190476
# 10009     0.032258  0.043011  0.043011
#
# [10 rows x 212 columns]

# %%
file_path = 'data/SignalDoc.csv'
continuous_attributes, discrete_attributes = attributes_type(file_path=file_path)
# Out:
# %%%%%%%%%% Attributes Type %%%%%%%%%%
# Number of continuous attributes: 179
# Number of discrete attributes: 33
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
continuous_info_df = continuous_attributes_description(data=data, column_name=continuous_attributes)
continuous_info_df.head(n=10)
# Out:
#             attribute          min           max       mean  nan_ratio
# 0    AbnormalAccruals    -2.809462      7.640322   0.000061   0.531029
# 1            Accruals   -11.619047     12.460567   0.031169   0.403137
# 2           Activism1     6.000000     23.000000  14.886500   0.979187
# 3                  AM     0.000000  12309.613000   3.679108   0.438305
# 4     AnalystRevision -1046.000000   5783.554200   1.006447   0.649389
# 5  AnnouncementReturn    -1.608569      9.453482   0.002650   0.464024
# 6         AssetGrowth -1071.381000      1.000000  -0.177109   0.396367
# 7     BetaLiquidityPS   -23.852209      8.508837  -0.000942   0.375915
# 8        BetaTailRisk   -10.737370      6.295467   0.641241   0.573134
# 9             betaVIX    -1.987414      1.579999  -0.000460   0.398593

# %%
discrete_info_df = discrete_attributes_description(data=data, column_name=discrete_attributes)
discrete_info_df.head(n=10)
# Out:
#            attribute  unique_values  min  max      mean  nan_ratio
# 0         AccrualsBM              2  0.0  1.0  0.483201   0.959166
# 1  ChForecastAccrual              2  0.0  1.0  0.476500   0.885485
# 2         ChNAnalyst              2 -1.0  0.0 -0.145632   0.962925
# 3        CitationsRD              2  0.0  1.0  0.225929   0.882245
# 4           ConvDebt              2 -1.0  0.0 -0.134623   0.334897
# 5          CredRatDG              2 -1.0  0.0 -0.017013   0.582908
# 6            DivInit              2  0.0  1.0  0.019445   0.248015
# 7            DivOmit              2 -1.0  0.0 -0.003915   0.248015
# 8          DivSeason              2  0.0  1.0  0.445729   0.667093
# 9         DivYieldST              4  0.0  3.0  0.628913   0.702136

# %%
metrics_evolution = evolution_over_time(data=data)
# Out:
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/ml_finance/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
selected_continuous_attributes = select_attributes_nan(attributes_infos=continuous_info_df, max_nan_ratio=0.6)
selected_discrete_attributes = select_attributes_nan(attributes_infos=discrete_info_df, max_nan_ratio=0.6)

print(f"Number of selected attributes: {len(selected_continuous_attributes) + len(selected_discrete_attributes)}\n"
      f"Continuous: {len(selected_continuous_attributes)}\n"
      f"Discrete: {len(selected_discrete_attributes)}")
# Out:
# Number of selected attributes: 118
# Continuous: 108
# Discrete: 10

# %% [markdown]
# ## Data cleaning

# %%
# Uncomment following line if you want to make the analysis over a specific time window
data_time_range = select_time_window(data=data, from_=1980, to_=2020)
print(data_time_range.shape)
# Out:
# (3742700, 215)

# %%
asset_info_df,  ratio_nan_attributes = assets_information(data=data_time_range)
display(asset_info_df.head(n=10))
display(ratio_nan_attributes.head(n=10))
# Out:
# %%%%%%%%%% Asset Information %%%%%%%%%%
# Number of assets: 31212
# Oldest date in dataset: 1980-01-01 00:00:00
# Latest date in dataset: 2020-12-01 00:00:00
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#    permno  data_quantity  date_from    date_to  month_window  ratio_nan_price  \
# 0   10000             28 1985-12-01 1988-03-01            27         0.392857
# 1   10001            390 1985-12-01 2018-05-01           389         0.028205
# 2   10002            330 1985-12-01 2013-05-01           329         0.015152
# 3   10003            126 1985-12-01 1996-05-01           125         0.055556
# 4   10004              1 1986-01-01 1986-01-01             0         1.000000
# 5   10005             78 1985-12-01 1992-05-01            77         0.153846
# 6   10006             65 1980-01-01 1985-05-01            64         0.184615
# 7   10007             60 1985-12-01 1990-11-01            59         0.283333
# 8   10008             42 1985-12-01 1989-05-01            41         0.190476
# 9   10009            186 1985-12-01 2001-05-01           185         0.043011
#
#    ratio_nan_overall
# 0           0.886989
# 1           0.399362
# 2           0.530531
# 3           0.753447
# 4           0.985915
# 5           0.645420
# 6           0.386782
# 7           0.770970
# 8           0.696401
# 9           0.651068
#               AM       AOP  AbnormalAccruals  Accruals  AccrualsBM  Activism1  \
# permno
# 10000   0.928571  1.000000          1.000000  1.000000    1.000000        1.0
# 10001   0.071795  0.784615          0.107692  0.092308    0.971795        1.0
# 10002   0.321212  0.854545          1.000000  0.345455    1.000000        1.0
# 10003   0.896825  1.000000          1.000000  0.944444    1.000000        1.0
# 10004   1.000000  1.000000          1.000000  1.000000    1.000000        1.0
# 10005   0.371795  1.000000          0.384615  0.384615    1.000000        1.0
# 10006   0.184615  1.000000          0.000000  0.000000    0.953846        1.0
# 10007   0.633333  1.000000          0.800000  0.800000    1.000000        1.0
# 10008   0.523810  0.428571          0.714286  0.714286    0.976190        1.0
# 10009   0.586022  1.000000          1.000000  0.612903    1.000000        1.0
#
#         Activism2     AdExp    AgeIPO  AnalystRevision  ...  skew1  std_turn  \
# permno                                                  ...
# 10000         1.0  0.928571  1.000000         1.000000  ...    1.0  1.000000
# 10001         1.0  1.000000  1.000000         0.451282  ...    1.0  0.087179
# 10002         1.0  0.527273  0.896970         0.730303  ...    1.0  0.084848
# 10003         1.0  1.000000  0.730159         0.817460  ...    1.0  0.238095
# 10004         1.0  1.000000  1.000000         1.000000  ...    1.0  1.000000
# 10005         1.0  1.000000  1.000000         1.000000  ...    1.0  0.448718
# 10006         1.0  0.184615  1.000000         1.000000  ...    1.0  1.000000
# 10007         1.0  0.633333  1.000000         1.000000  ...    1.0  1.000000
# 10008         1.0  0.523810  0.261905         0.404762  ...    1.0  0.785714
# 10009         1.0  0.586022  1.000000         0.844086  ...    1.0  0.166667
#
#             tang  zerotrade  zerotradeAlt1  zerotradeAlt12  STreversal  \
# permno
# 10000   0.571429   0.535714       0.392857        0.785714    0.321429
# 10001   1.000000   0.038462       0.028205        0.056410    0.023077
# 10002   1.000000   0.027273       0.015152        0.048485    0.009091
# 10003   1.000000   0.087302       0.055556        0.142857    0.039683
# 10004   1.000000   1.000000       1.000000        1.000000    1.000000
# 10005   1.000000   0.589744       0.243590        0.794872    0.128205
# 10006   0.000000   0.169231       0.169231        0.169231    0.169231
# 10007   1.000000   0.416667       0.266667        0.633333    0.016667
# 10008   0.428571   0.285714       0.190476        0.452381    0.142857
# 10009   1.000000   0.064516       0.043011        0.102151    0.032258
#
#            Price      Size  year
# permno
# 10000   0.392857  0.392857   0.0
# 10001   0.028205  0.028205   0.0
# 10002   0.015152  0.015152   0.0
# 10003   0.055556  0.055556   0.0
# 10004   1.000000  1.000000   0.0
# 10005   0.153846  0.153846   0.0
# 10006   0.184615  0.184615   0.0
# 10007   0.283333  0.283333   0.0
# 10008   0.190476  0.190476   0.0
# 10009   0.043011  0.043011   0.0
#
# [10 rows x 213 columns]

# %%
continuous_info_df = continuous_attributes_description(data=data_time_range, column_name=continuous_attributes)
continuous_info_df.head(n=10)
# Out:
#             attribute          min           max       mean  nan_ratio
# 0    AbnormalAccruals    -2.218069      7.640322   0.000007   0.433571
# 1            Accruals   -11.619047     12.460567   0.035122   0.335382
# 2           Activism1     6.000000     23.000000  14.886500   0.970949
# 3                  AM     0.000000  12309.613000   3.830445   0.381417
# 4     AnalystRevision -1046.000000   5783.554200   1.005314   0.551599
# 5  AnnouncementReturn    -1.608569      9.453482   0.002686   0.343583
# 6         AssetGrowth -1071.381000      1.000000  -0.181722   0.331902
# 7     BetaLiquidityPS   -23.852209      8.508837   0.002252   0.292860
# 8        BetaTailRisk   -10.737370      6.295467   0.725536   0.578020
# 9             betaVIX    -1.987414      1.579999  -0.000453   0.180872

# %%
discrete_info_df = discrete_attributes_description(data=data_time_range, column_name=discrete_attributes)
discrete_info_df.head(n=10)
# Out:
#            attribute  unique_values  min  max      mean  nan_ratio
# 0         AccrualsBM              2  0.0  1.0  0.484291   0.953032
# 1  ChForecastAccrual              2  0.0  1.0  0.467947   0.853686
# 2         ChNAnalyst              2 -1.0  0.0 -0.149003   0.951949
# 3        CitationsRD              2  0.0  1.0  0.244121   0.851739
# 4           ConvDebt              2 -1.0  0.0 -0.123055   0.266245
# 5          CredRatDG              2 -1.0  0.0 -0.017351   0.429153
# 6            DivInit              2  0.0  1.0  0.014306   0.268827
# 7            DivOmit              2 -1.0  0.0 -0.003535   0.268827
# 8          DivSeason              2  0.0  1.0  0.434669   0.733083
# 9         DivYieldST              4  0.0  3.0  0.627605   0.743188

# %%
selected_continuous_attributes = select_attributes_nan(attributes_infos=continuous_info_df, max_nan_ratio=0.6)
selected_discrete_attributes = select_attributes_nan(attributes_infos=discrete_info_df, max_nan_ratio=0.6)

print(f"Number of selected attributes: {len(selected_continuous_attributes) + len(selected_discrete_attributes)}\n\n"
      f"Continuous: {len(selected_continuous_attributes)}\n"
      f"{selected_continuous_attributes['attribute'].to_list()}\n\n"
      f"Discrete: {len(selected_discrete_attributes)}\n"
      f"{selected_discrete_attributes['attribute'].to_list()}")
# Out:
# Number of selected attributes: 129
#
# Continuous: 119
# ['AbnormalAccruals', 'Accruals', 'AM', 'AnalystRevision', 'AnnouncementReturn', 'AssetGrowth', 'BetaLiquidityPS', 'BetaTailRisk', 'betaVIX', 'BM', 'BMdec', 'BookLeverage', 'BPEBM', 'Cash', 'CashProd', 'CBOperProf', 'CF', 'cfp', 'ChAssetTurnover', 'ChEQ', 'ChInv', 'ChInvIA', 'ChNNCOA', 'ChNWC', 'ChTax', 'CompEquIss', 'CoskewACX', 'DelCOA', 'DelCOL', 'DelEqu', 'DelFINL', 'DelLTI', 'DelNetFin', 'dNoa', 'DolVol', 'EarningsSurprise', 'EarnSupBig', 'EBM', 'EntMult', 'EP', 'EquityDuration', 'ExclExp', 'FEPS', 'GP', 'grcapx', 'grcapx3y', 'Herf', 'HerfBE', 'hire', 'IdioVol3F', 'IdioVolAHT', 'Illiquidity', 'IndMom', 'IndRetBig', 'IntMom', 'Investment', 'InvestPPEInv', 'iomom_cust', 'iomom_supp', 'Leverage', 'LRreversal', 'MaxRet', 'MeanRankRevGrowth', 'Mom12m', 'Mom12mOffSeason', 'Mom6m', 'MomOffSeason', 'MomOffSeason06YrPlus', 'MomSeason', 'MomSeason06YrPlus', 'MomSeasonShort', 'NetDebtFinance', 'NetEquityFinance', 'NOA', 'OPLeverage', 'PctAcc', 'PctTotAcc', 'Price', 'PriceDelayRsq', 'RDS', 'RealizedVol', 'ResidualMomentum', 'ReturnSkew', 'ReturnSkew3F', 'REV6', 'RevenueSurprise', 'roaq', 'ShareIss1Y', 'ShareIss5Y', 'Size', 'std_turn', 'STreversal', 'Tax', 'TotalAccruals', 'VolSD', 'XFIN', 'zerotrade', 'zerotradeAlt1', 'zerotradeAlt12', 'Beta', 'BetaFP', 'BidAskSpread', 'Coskewness', 'FirmAge', 'GrLTNOA', 'GrSaleToGrInv', 'GrSaleToGrOverhead', 'HerfAsset', 'High52', 'MRreversal', 'NumEarnIncrease', 'OperProfRD', 'PriceDelaySlope', 'PriceDelayTstat', 'RoE', 'SP', 'VarCF', 'VolMkt', 'VolumeTrend']
#
# Discrete: 10
# ['ConvDebt', 'CredRatDG', 'DivInit', 'DivOmit', 'ExchSwitch', 'IndIPO', 'RDIPO', 'DebtIssuance', 'ShareRepurchase', 'Spinoff']

# %% [markdown]
# ## Results
#
# Try to show relevant correlation or information about different potential predictors in our dataset.

# %%
medium_quality_attribute = ['permno', 'date'] \
                           + selected_continuous_attributes['attribute'].to_list() \
                           + selected_discrete_attributes['attribute'].to_list()

data_reduced_attribute = data_time_range[medium_quality_attribute]
print(data_reduced_attribute.shape)
# Out:
# (3742700, 131)

# %%
# Calculate the maximum number of NaN values allowed in a row
max_nan_values = len(data_reduced_attribute.columns) * 0.15
# Filter the DataFrame to select rows with less than 15% NaN values
data_reduced = data_reduced_attribute[data_reduced_attribute.isna().sum(axis=1) < max_nan_values].reset_index(drop=True)
print(data_reduced.shape)
# Out:
# (1760578, 131)

# %%
# Store the selected data to work with
data_reduced.to_csv('data/data_reduce.csv', index=False)
